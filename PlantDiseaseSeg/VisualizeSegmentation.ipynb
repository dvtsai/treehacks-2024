# %% [markdown]
# ## Visualize the PlantDisease Segmentation Dataset

# %% [markdown]
# #### Prerequisite: Download the dataset

# %%
https://www.kaggle.com/datasets/fakhrealam9537/leaf-disease-segmentation-dataset?select=data

# %% [markdown]
# #### Import the necessary dependencies

# %%
from segdataset import SegmentationDataset
from torch.utils.data import DataLoader
from torchvision import transforms

# %% [markdown]
# #### Load data and dataloader

# %%
plant_disease_dataset = SegmentationDataset("./LeafDisease/")
plant_disease_dataloader = DataLoader(seg_dataset, batch_size=32, shuffle=False, num_workers=8)
samples = next(iter(plant_disease_dataloader))
# Out:
# hello hello

# %% [markdown]
# #### Generate a sample image

# %%
# Display the image and mask tensor shape
# We see the tensor size is correct bxcxhxw, where b is batch size, c is number of channels, h is height, w is width
display(samples['image'].shape,
samples['mask'].shape)
# Out:
# torch.Size([32, 3, 256, 256])
# torch.Size([32, 1, 256, 256])

# %% [markdown]
# #### Create a sample image and mask pair

# %%
img = transforms.ToPILImage()(samples['image'][5])
mask = transforms.ToPILImage()(samples['mask'][5])

# %% [markdown]
# #### Display image and mask

# %%
display(img, mask)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=L size=256x256>
